# %% [markdown]
# # Fashion MNIST Classification

# %%
# Setup
import tensorflow as tf
import keras

import numpy as np
import datetime

import os
import sys
import imp

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import models as M
import utils as U
import dataset as D

imp.reload(M)
imp.reload(U)
imp.reload(D)
# Out:
# <module 'dataset' from '/Users/mghifary/Work/Code/AI/keras-poc/dataset.py'>

# %% [markdown]
# ### Constants

# %%
EPOCH = 30
BATCH = 128

DATADIR = "/Users/mghifary/Work/Code/AI/data"
MODELDIR = "/Users/mghifary/Work/Code/AI/models"

# %% [markdown]
# ### Load and preprocess dataset

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = D.load_data()

# Reshape
x_train = np.expand_dims(x_train, axis=-1) 
x_test = np.expand_dims(x_test, axis=-1)

(n_train, dx1, dx2, c) = x_train.shape
n_test = x_test.shape[0]

ds_train = tf.data.Dataset.from_tensor_slices((x_train, y_train))
ds_test = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# Preprocess
ds_train = D.preprocess_fashionmnist(ds_train, shuffle=True, augment=False, batch_size=BATCH)
ds_test = D.preprocess_fashionmnist(ds_test, shuffle=False, augment=False, batch_size=BATCH)

# %% [markdown]
# ### Visualize data

# %%
# Visualize training samples
U.visualize_dataset(ds_train, title="Fashion MNIST Training", n_samples=25)

# %%
# Visualize test samples
U.visualize_dataset(ds_test, title="Fashion MNIST Testing", n_samples=25)

# %% [markdown]
# ### Build NN model

# %%
# Sequential model
model = M.MLPSeq(num_classes=10)
model.build(input_shape=(None, dx1, dx2, c))
model.summary()
# Out:
# Model: "mlp_seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235146 (918.54 KB)
# Trainable params: 235146 (918.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# # Functional API
# model = M.make_mlp(input_shape=(dx1, dx2, c), num_classes=10)
# model.summary()

# %%
# # Subclassing API
# model = M.MLP(num_classes=10)
# model.build(input_shape=(None, dx1, dx2, c))
# model.summary()
# Out:
# Model: "mlp"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           multiple                  0
#
#  dense (Dense)               multiple                  200960
#
#  dense_1 (Dense)             multiple                  32896
#
#  dense_2 (Dense)             multiple                  1290
#
# =================================================================
# Total params: 235146 (918.54 KB)
# Trainable params: 235146 (918.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Train model

# %%
# Loss and optimizer
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
accuracy = keras.metrics.SparseCategoricalAccuracy()
optimizer = keras.optimizers.legacy.Adam(learning_rate=3e-4)

# %%
# Define callback for Tensorboard and Model Checkpoint
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = keras.callbacks.TensorBoard(
    log_dir="./logs/mlp-fashionmnist/" + current_time,
    update_freq="epoch"
)

checkpoint_dir = os.path.join(MODELDIR, f"mlp-fashionmnist-{current_time}")

if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

checkpoint_filepath = os.path.join(checkpoint_dir, "weights-{epoch:02d}-{val_loss:.2f}.hdf5")
modelcp_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True
)

# %%
# Compile and run training
model.compile(optimizer=optimizer, loss=loss_fn, metrics=[accuracy])
model.fit(ds_train, epochs=EPOCH, validation_data=ds_test, callbacks=[tensorboard_callback, modelcp_callback])
# Out:
# Epoch 1/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.6109 - sparse_categorical_accuracy: 0.7943 - val_loss: 0.4583 - val_sparse_categorical_accuracy: 0.8378
# Epoch 2/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.4070 - sparse_categorical_accuracy: 0.8569 - val_loss: 0.4083 - val_sparse_categorical_accuracy: 0.8548
# Epoch 3/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3659 - sparse_categorical_accuracy: 0.8700 - val_loss: 0.4112 - val_sparse_categorical_accuracy: 0.8518
# Epoch 4/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3396 - sparse_categorical_accuracy: 0.8786 - val_loss: 0.3953 - val_sparse_categorical_accuracy: 0.8584
# Epoch 5/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3165 - sparse_categorical_accuracy: 0.8868 - val_loss: 0.3640 - val_sparse_categorical_accuracy: 0.8666
# Epoch 6/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3017 - sparse_categorical_accuracy: 0.8917 - val_loss: 0.3503 - val_sparse_categorical_accuracy: 0.8751
# Epoch 7/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2893 - sparse_categorical_accuracy: 0.8949 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8764
# Epoch 8/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2768 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.3570 - val_sparse_categorical_accuracy: 0.8701
# Epoch 9/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2661 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.3336 - val_sparse_categorical_accuracy: 0.8795
# Epoch 10/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2568 - sparse_categorical_accuracy: 0.9064 - val_loss: 0.3380 - val_sparse_categorical_accuracy: 0.8775
# Epoch 11/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2497 - sparse_categorical_accuracy: 0.9093 - val_loss: 0.3343 - val_sparse_categorical_accuracy: 0.8806
# Epoch 12/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2385 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.3277 - val_sparse_categorical_accuracy: 0.8820
# Epoch 13/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2318 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.3279 - val_sparse_categorical_accuracy: 0.8824
# Epoch 14/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2252 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.8814
# Epoch 15/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2181 - sparse_categorical_accuracy: 0.9211 - val_loss: 0.3257 - val_sparse_categorical_accuracy: 0.8825
# Epoch 16/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2130 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.3254 - val_sparse_categorical_accuracy: 0.8835
# Epoch 17/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2051 - sparse_categorical_accuracy: 0.9248 - val_loss: 0.3208 - val_sparse_categorical_accuracy: 0.8872
# Epoch 18/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1992 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.3187 - val_sparse_categorical_accuracy: 0.8900
# Epoch 19/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1929 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.3330 - val_sparse_categorical_accuracy: 0.8852
# Epoch 20/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9318 - val_loss: 0.3212 - val_sparse_categorical_accuracy: 0.8882
# Epoch 21/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1794 - sparse_categorical_accuracy: 0.9351 - val_loss: 0.3257 - val_sparse_categorical_accuracy: 0.8880
# Epoch 22/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1761 - sparse_categorical_accuracy: 0.9362 - val_loss: 0.3352 - val_sparse_categorical_accuracy: 0.8856
# Epoch 23/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1715 - sparse_categorical_accuracy: 0.9369 - val_loss: 0.3443 - val_sparse_categorical_accuracy: 0.8866
# Epoch 24/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1659 - sparse_categorical_accuracy: 0.9403 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8875
# Epoch 25/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1591 - sparse_categorical_accuracy: 0.9424 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8888
# Epoch 26/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1552 - sparse_categorical_accuracy: 0.9438 - val_loss: 0.3427 - val_sparse_categorical_accuracy: 0.8862
# Epoch 27/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.3331 - val_sparse_categorical_accuracy: 0.8901
# Epoch 28/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1458 - sparse_categorical_accuracy: 0.9474 - val_loss: 0.3435 - val_sparse_categorical_accuracy: 0.8881
# Epoch 29/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1414 - sparse_categorical_accuracy: 0.9491 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.8888
# Epoch 30/30
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1402 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.3553 - val_sparse_categorical_accuracy: 0.8891
